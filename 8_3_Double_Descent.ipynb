# %% [markdown]
# <a href="https://colab.research.google.com/github/amanichopra/understanding-deep-learning-textbook-exercises/blob/main/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-k6j48pq1
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-k6j48pq1
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=f98559e9b60d55b51b5f249878baa83ffc148424eef6b8e68f2296a72d3d5f48
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oyhe40it/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301807, train error 89.70,  test loss 2.303111, test error 90.53
# Epoch   100, train loss 1.869104, train error 71.22,  test loss 1.731643, test error 69.55
# Epoch   200, train loss 1.853388, train error 70.85,  test loss 1.709725, test error 67.85
# Epoch   300, train loss 1.849095, train error 70.43,  test loss 1.703663, test error 68.15
# Epoch   400, train loss 1.848225, train error 70.15,  test loss 1.707380, test error 68.15
# Epoch   500, train loss 1.842100, train error 69.75,  test loss 1.696670, test error 67.43
# Epoch   600, train loss 1.842268, train error 69.85,  test loss 1.704049, test error 67.80
# Epoch   700, train loss 1.844591, train error 70.05,  test loss 1.696473, test error 67.65
# Epoch   800, train loss 1.841706, train error 69.72,  test loss 1.700536, test error 68.03
# Epoch   900, train loss 1.842475, train error 69.70,  test loss 1.695467, test error 67.68
# Training model with   4 hidden variables
# Epoch     0, train loss 2.190611, train error 82.00,  test loss 2.151847, test error 80.62
# Epoch   100, train loss 1.808388, train error 67.78,  test loss 1.673871, test error 65.68
# Epoch   200, train loss 1.790480, train error 67.22,  test loss 1.681849, test error 65.00
# Epoch   300, train loss 1.784417, train error 66.50,  test loss 1.670662, test error 65.25
# Epoch   400, train loss 1.782471, train error 66.47,  test loss 1.665286, test error 65.57
# Epoch   500, train loss 1.778611, train error 66.57,  test loss 1.665523, test error 65.40
# Epoch   600, train loss 1.774522, train error 67.00,  test loss 1.667984, test error 65.68
# Epoch   700, train loss 1.772647, train error 66.18,  test loss 1.670428, test error 65.40
# Epoch   800, train loss 1.775144, train error 66.62,  test loss 1.666577, test error 65.80
# Epoch   900, train loss 1.772811, train error 66.30,  test loss 1.670141, test error 66.03
# Training model with   6 hidden variables
# Epoch     0, train loss 2.222847, train error 80.90,  test loss 2.194377, test error 79.70
# Epoch   100, train loss 1.724314, train error 62.40,  test loss 1.582286, test error 61.70
# Epoch   200, train loss 1.660432, train error 58.40,  test loss 1.528620, test error 57.60
# Epoch   300, train loss 1.617640, train error 56.92,  test loss 1.514727, test error 57.30
# Epoch   400, train loss 1.610813, train error 57.10,  test loss 1.511547, test error 57.30
# Epoch   500, train loss 1.611276, train error 56.78,  test loss 1.517585, test error 57.92
# Epoch   600, train loss 1.608691, train error 57.30,  test loss 1.522736, test error 57.50
# Epoch   700, train loss 1.603072, train error 56.97,  test loss 1.522274, test error 57.30
# Epoch   800, train loss 1.603524, train error 56.60,  test loss 1.524466, test error 57.42
# Epoch   900, train loss 1.599280, train error 56.00,  test loss 1.526237, test error 57.35
# Training model with   8 hidden variables
# Epoch     0, train loss 2.195272, train error 83.40,  test loss 2.163650, test error 83.40
# Epoch   100, train loss 1.643332, train error 57.53,  test loss 1.510308, test error 57.30
# Epoch   200, train loss 1.608292, train error 56.35,  test loss 1.531157, test error 57.70
# Epoch   300, train loss 1.597126, train error 56.12,  test loss 1.534727, test error 58.08
# Epoch   400, train loss 1.595614, train error 55.67,  test loss 1.536524, test error 58.05
# Epoch   500, train loss 1.588421, train error 55.28,  test loss 1.535421, test error 58.35
# Epoch   600, train loss 1.586239, train error 55.72,  test loss 1.526845, test error 58.47
# Epoch   700, train loss 1.581853, train error 55.28,  test loss 1.541500, test error 58.45
# Epoch   800, train loss 1.584971, train error 54.83,  test loss 1.546103, test error 58.70
# Epoch   900, train loss 1.577303, train error 54.90,  test loss 1.542425, test error 58.05
# Training model with  10 hidden variables
# Epoch     0, train loss 2.274317, train error 85.60,  test loss 2.266132, test error 83.90
# Epoch   100, train loss 1.580417, train error 56.20,  test loss 1.470933, test error 56.30
# Epoch   200, train loss 1.535162, train error 54.67,  test loss 1.465451, test error 55.90
# Epoch   300, train loss 1.511917, train error 53.60,  test loss 1.466418, test error 55.53
# Epoch   400, train loss 1.495606, train error 52.45,  test loss 1.476171, test error 54.85
# Epoch   500, train loss 1.492548, train error 52.45,  test loss 1.503686, test error 55.78
# Epoch   600, train loss 1.478380, train error 52.30,  test loss 1.497153, test error 55.42
# Epoch   700, train loss 1.477951, train error 52.22,  test loss 1.518920, test error 55.40
# Epoch   800, train loss 1.473114, train error 52.28,  test loss 1.513884, test error 56.08
# Epoch   900, train loss 1.472457, train error 52.08,  test loss 1.522637, test error 55.50
# Training model with  14 hidden variables
# Epoch     0, train loss 2.237203, train error 84.47,  test loss 2.215798, test error 82.82
# Epoch   100, train loss 1.461573, train error 49.55,  test loss 1.372539, test error 52.75
# Epoch   200, train loss 1.372032, train error 46.15,  test loss 1.347166, test error 50.53
# Epoch   300, train loss 1.335563, train error 45.80,  test loss 1.372948, test error 50.78
# Epoch   400, train loss 1.316781, train error 44.60,  test loss 1.394673, test error 50.28
# Epoch   500, train loss 1.317818, train error 44.62,  test loss 1.429020, test error 50.97
# Epoch   600, train loss 1.293130, train error 43.83,  test loss 1.436798, test error 51.55
# Epoch   700, train loss 1.284820, train error 43.60,  test loss 1.451184, test error 51.85
# Epoch   800, train loss 1.282316, train error 43.38,  test loss 1.459822, test error 51.75
# Epoch   900, train loss 1.278521, train error 43.92,  test loss 1.479668, test error 52.45
# Training model with  18 hidden variables
# Epoch     0, train loss 2.174226, train error 80.35,  test loss 2.151630, test error 80.45
# Epoch   100, train loss 1.327918, train error 44.70,  test loss 1.302619, test error 47.97
# Epoch   200, train loss 1.234081, train error 42.00,  test loss 1.344810, test error 49.83
# Epoch   300, train loss 1.189682, train error 40.67,  test loss 1.366109, test error 48.95
# Epoch   400, train loss 1.174601, train error 40.20,  test loss 1.404248, test error 50.33
# Epoch   500, train loss 1.166020, train error 40.00,  test loss 1.413895, test error 49.90
# Epoch   600, train loss 1.142974, train error 38.97,  test loss 1.438698, test error 50.65
# Epoch   700, train loss 1.131529, train error 38.08,  test loss 1.431208, test error 50.53
# Epoch   800, train loss 1.123811, train error 38.30,  test loss 1.459875, test error 50.28
# Epoch   900, train loss 1.120479, train error 37.78,  test loss 1.473874, test error 49.83
# Training model with  22 hidden variables
# Epoch     0, train loss 2.165836, train error 82.00,  test loss 2.144437, test error 81.53
# Epoch   100, train loss 1.256799, train error 42.50,  test loss 1.264615, test error 47.40
# Epoch   200, train loss 1.144734, train error 38.83,  test loss 1.298917, test error 47.25
# Epoch   300, train loss 1.084538, train error 36.88,  test loss 1.379413, test error 49.35
# Epoch   400, train loss 1.049859, train error 35.60,  test loss 1.431230, test error 50.80
# Epoch   500, train loss 1.027019, train error 35.68,  test loss 1.485776, test error 50.38
# Epoch   600, train loss 0.994439, train error 34.30,  test loss 1.508969, test error 50.17
# Epoch   700, train loss 0.990917, train error 34.22,  test loss 1.568542, test error 51.38
# Epoch   800, train loss 0.968548, train error 33.57,  test loss 1.592872, test error 51.80
# Epoch   900, train loss 0.974503, train error 34.38,  test loss 1.608273, test error 51.03
# Training model with  26 hidden variables
# Epoch     0, train loss 2.130666, train error 79.45,  test loss 2.088649, test error 77.70
# Epoch   100, train loss 1.199995, train error 40.12,  test loss 1.351125, test error 49.85
# Epoch   200, train loss 1.046293, train error 35.38,  test loss 1.455302, test error 50.72
# Epoch   300, train loss 0.971137, train error 33.18,  test loss 1.594048, test error 51.30
# Epoch   400, train loss 0.952852, train error 32.55,  test loss 1.711148, test error 53.38
# Epoch   500, train loss 0.911119, train error 32.25,  test loss 1.782768, test error 52.85
# Epoch   600, train loss 0.887080, train error 30.97,  test loss 1.804106, test error 53.28
# Epoch   700, train loss 0.884679, train error 31.20,  test loss 1.867090, test error 53.85
# Epoch   800, train loss 0.862270, train error 29.75,  test loss 1.900296, test error 53.65
# Epoch   900, train loss 0.860079, train error 30.20,  test loss 1.954904, test error 54.45
# Training model with  30 hidden variables
# Epoch     0, train loss 2.140040, train error 79.32,  test loss 2.105994, test error 79.55
# Epoch   100, train loss 1.108972, train error 36.58,  test loss 1.283405, test error 47.22
# Epoch   200, train loss 0.927116, train error 30.68,  test loss 1.523556, test error 50.38
# Epoch   300, train loss 0.828838, train error 27.70,  test loss 1.689582, test error 51.15
# Epoch   400, train loss 0.773081, train error 26.25,  test loss 1.914424, test error 52.92
# Epoch   500, train loss 0.730880, train error 25.45,  test loss 2.057912, test error 53.20
# Epoch   600, train loss 0.708799, train error 24.20,  test loss 2.217330, test error 54.15
# Epoch   700, train loss 0.691713, train error 23.70,  test loss 2.329669, test error 54.42
# Epoch   800, train loss 0.683949, train error 23.68,  test loss 2.435864, test error 54.80
# Epoch   900, train loss 0.658629, train error 22.82,  test loss 2.537979, test error 54.60
# Training model with  35 hidden variables
# Epoch     0, train loss 2.188572, train error 79.75,  test loss 2.176768, test error 79.72
# Epoch   100, train loss 0.992146, train error 32.57,  test loss 1.374898, test error 50.15
# Epoch   200, train loss 0.757214, train error 25.32,  test loss 1.761481, test error 52.60
# Epoch   300, train loss 0.641974, train error 21.85,  test loss 2.156525, test error 53.50
# Epoch   400, train loss 0.576333, train error 19.80,  test loss 2.506182, test error 54.70
# Epoch   500, train loss 0.534584, train error 18.30,  test loss 2.874494, test error 55.50
# Epoch   600, train loss 0.500972, train error 17.60,  test loss 3.206874, test error 56.17
# Epoch   700, train loss 0.465047, train error 15.95,  test loss 3.551309, test error 55.88
# Epoch   800, train loss 0.466824, train error 16.40,  test loss 3.834112, test error 56.35
# Epoch   900, train loss 0.470918, train error 16.85,  test loss 4.119243, test error 56.22
# Training model with  40 hidden variables
# Epoch     0, train loss 2.054984, train error 76.97,  test loss 1.998090, test error 76.22
# Epoch   100, train loss 0.931959, train error 30.35,  test loss 1.423219, test error 48.85
# Epoch   200, train loss 0.636465, train error 19.93,  test loss 1.920399, test error 52.17
# Epoch   300, train loss 0.511730, train error 15.75,  test loss 2.505666, test error 53.78
# Epoch   400, train loss 0.419679, train error 13.38,  test loss 3.167120, test error 54.92
# Epoch   500, train loss 0.368977, train error 11.82,  test loss 3.783367, test error 56.15
# Epoch   600, train loss 0.317633, train error 9.95,  test loss 4.418573, test error 56.17
# Epoch   700, train loss 0.286076, train error 9.00,  test loss 5.018775, test error 56.80
# Epoch   800, train loss 0.319611, train error 11.10,  test loss 5.777883, test error 57.38
# Epoch   900, train loss 0.239369, train error 8.32,  test loss 6.253885, test error 56.70
# Training model with  45 hidden variables
# Epoch     0, train loss 2.053721, train error 76.78,  test loss 2.017388, test error 76.28
# Epoch   100, train loss 0.838586, train error 26.72,  test loss 1.475473, test error 49.58
# Epoch   200, train loss 0.502550, train error 16.53,  test loss 2.216534, test error 53.42
# Epoch   300, train loss 0.288618, train error 8.07,  test loss 3.190177, test error 54.33
# Epoch   400, train loss 0.219575, train error 7.22,  test loss 4.446404, test error 56.03
# Epoch   500, train loss 0.166401, train error 5.20,  test loss 5.524386, test error 55.53
# Epoch   600, train loss 0.176457, train error 6.25,  test loss 6.640002, test error 56.40
# Epoch   700, train loss 0.018215, train error 0.03,  test loss 7.721253, test error 56.55
# Epoch   800, train loss 0.010864, train error 0.00,  test loss 8.539054, test error 56.78
# Epoch   900, train loss 0.007731, train error 0.00,  test loss 9.135051, test error 56.80
# Training model with  50 hidden variables
# Epoch     0, train loss 2.107845, train error 77.78,  test loss 2.079105, test error 78.12
# Epoch   100, train loss 0.753766, train error 23.82,  test loss 1.533219, test error 50.05
# Epoch   200, train loss 0.383868, train error 12.12,  test loss 2.497530, test error 54.08
# Epoch   300, train loss 0.182143, train error 4.80,  test loss 3.836298, test error 54.17
# Epoch   400, train loss 0.043074, train error 0.07,  test loss 5.418585, test error 55.97
# Epoch   500, train loss 0.014661, train error 0.00,  test loss 6.438625, test error 55.83
# Epoch   600, train loss 0.009236, train error 0.00,  test loss 7.094386, test error 56.20
# Epoch   700, train loss 0.006742, train error 0.00,  test loss 7.571526, test error 56.22
# Epoch   800, train loss 0.005086, train error 0.00,  test loss 7.950480, test error 56.38
# Epoch   900, train loss 0.004093, train error 0.00,  test loss 8.272161, test error 56.38
# Training model with  55 hidden variables
# Epoch     0, train loss 2.067499, train error 77.45,  test loss 2.013052, test error 77.00
# Epoch   100, train loss 0.636939, train error 20.30,  test loss 1.690388, test error 50.38
# Epoch   200, train loss 0.220947, train error 5.40,  test loss 3.031291, test error 52.38
# Epoch   300, train loss 0.037513, train error 0.07,  test loss 4.749196, test error 53.65
# Epoch   400, train loss 0.014202, train error 0.00,  test loss 5.756861, test error 53.60
# Epoch   500, train loss 0.008201, train error 0.00,  test loss 6.368246, test error 53.80
# Epoch   600, train loss 0.005684, train error 0.00,  test loss 6.808025, test error 53.95
# Epoch   700, train loss 0.004232, train error 0.00,  test loss 7.147377, test error 54.03
# Epoch   800, train loss 0.003355, train error 0.00,  test loss 7.425767, test error 53.90
# Epoch   900, train loss 0.002754, train error 0.00,  test loss 7.660521, test error 53.95
# Training model with  60 hidden variables
# Epoch     0, train loss 2.084214, train error 76.20,  test loss 2.060616, test error 76.82
# Epoch   100, train loss 0.485814, train error 13.70,  test loss 1.770315, test error 50.97
# Epoch   200, train loss 0.093725, train error 0.55,  test loss 3.454090, test error 53.58
# Epoch   300, train loss 0.019627, train error 0.00,  test loss 4.703088, test error 54.33
# Epoch   400, train loss 0.009545, train error 0.00,  test loss 5.382761, test error 54.38
# Epoch   500, train loss 0.006062, train error 0.00,  test loss 5.826203, test error 54.72
# Epoch   600, train loss 0.004369, train error 0.00,  test loss 6.158074, test error 54.55
# Epoch   700, train loss 0.003347, train error 0.00,  test loss 6.423594, test error 54.75
# Epoch   800, train loss 0.002692, train error 0.00,  test loss 6.639924, test error 54.85
# Epoch   900, train loss 0.002238, train error 0.00,  test loss 6.826054, test error 54.75
# Training model with  70 hidden variables
# Epoch     0, train loss 2.029119, train error 74.88,  test loss 1.988937, test error 75.85
# Epoch   100, train loss 0.341860, train error 7.57,  test loss 1.968944, test error 52.08
# Epoch   200, train loss 0.031371, train error 0.00,  test loss 3.681556, test error 53.67
# Epoch   300, train loss 0.010717, train error 0.00,  test loss 4.444330, test error 53.67
# Epoch   400, train loss 0.006002, train error 0.00,  test loss 4.885496, test error 53.85
# Epoch   500, train loss 0.004052, train error 0.00,  test loss 5.195268, test error 53.95
# Epoch   600, train loss 0.003018, train error 0.00,  test loss 5.429030, test error 53.95
# Epoch   700, train loss 0.002372, train error 0.00,  test loss 5.621100, test error 53.90
# Epoch   800, train loss 0.001945, train error 0.00,  test loss 5.781077, test error 54.00
# Epoch   900, train loss 0.001638, train error 0.00,  test loss 5.918723, test error 54.03
# Training model with  80 hidden variables
# Epoch     0, train loss 2.035954, train error 75.47,  test loss 1.962608, test error 74.40
# Epoch   100, train loss 0.229793, train error 4.03,  test loss 2.087119, test error 51.17
# Epoch   200, train loss 0.019352, train error 0.00,  test loss 3.422080, test error 52.58
# Epoch   300, train loss 0.007915, train error 0.00,  test loss 3.961941, test error 52.47
# Epoch   400, train loss 0.004714, train error 0.00,  test loss 4.291050, test error 52.88
# Epoch   500, train loss 0.003275, train error 0.00,  test loss 4.520891, test error 52.78
# Epoch   600, train loss 0.002475, train error 0.00,  test loss 4.702655, test error 52.67
# Epoch   700, train loss 0.001970, train error 0.00,  test loss 4.851436, test error 52.75
# Epoch   800, train loss 0.001624, train error 0.00,  test loss 4.974540, test error 52.62
# Epoch   900, train loss 0.001374, train error 0.00,  test loss 5.082594, test error 52.88
# Training model with  90 hidden variables
# Epoch     0, train loss 2.029405, train error 74.93,  test loss 1.969810, test error 74.00
# Epoch   100, train loss 0.153998, train error 1.65,  test loss 2.142837, test error 50.45
# Epoch   200, train loss 0.015510, train error 0.00,  test loss 3.244677, test error 51.12
# Epoch   300, train loss 0.006698, train error 0.00,  test loss 3.683757, test error 50.83
# Epoch   400, train loss 0.004113, train error 0.00,  test loss 3.957150, test error 51.15
# Epoch   500, train loss 0.002870, train error 0.00,  test loss 4.152305, test error 51.17
# Epoch   600, train loss 0.002186, train error 0.00,  test loss 4.305628, test error 51.22
# Epoch   700, train loss 0.001744, train error 0.00,  test loss 4.430022, test error 51.12
# Epoch   800, train loss 0.001444, train error 0.00,  test loss 4.536955, test error 50.97
# Epoch   900, train loss 0.001225, train error 0.00,  test loss 4.628572, test error 50.85
# Training model with 100 hidden variables
# Epoch     0, train loss 2.008435, train error 74.75,  test loss 1.943092, test error 75.45
# Epoch   100, train loss 0.086349, train error 0.07,  test loss 2.267948, test error 51.95
# Epoch   200, train loss 0.011907, train error 0.00,  test loss 3.112822, test error 51.65
# Epoch   300, train loss 0.005549, train error 0.00,  test loss 3.475182, test error 51.35
# Epoch   400, train loss 0.003470, train error 0.00,  test loss 3.700326, test error 51.20
# Epoch   500, train loss 0.002472, train error 0.00,  test loss 3.863657, test error 51.08
# Epoch   600, train loss 0.001897, train error 0.00,  test loss 3.990918, test error 50.90
# Epoch   700, train loss 0.001526, train error 0.00,  test loss 4.095842, test error 50.92
# Epoch   800, train loss 0.001268, train error 0.00,  test loss 4.185377, test error 50.92
# Epoch   900, train loss 0.001080, train error 0.00,  test loss 4.262189, test error 50.88
# Training model with 120 hidden variables
# Epoch     0, train loss 1.985487, train error 73.35,  test loss 1.919164, test error 72.53
# Epoch   100, train loss 0.052747, train error 0.00,  test loss 2.214418, test error 49.35
# Epoch   200, train loss 0.009554, train error 0.00,  test loss 2.849243, test error 49.45
# Epoch   300, train loss 0.004718, train error 0.00,  test loss 3.131262, test error 49.65
# Epoch   400, train loss 0.003014, train error 0.00,  test loss 3.311358, test error 49.75
# Epoch   500, train loss 0.002173, train error 0.00,  test loss 3.446516, test error 49.78
# Epoch   600, train loss 0.001678, train error 0.00,  test loss 3.553105, test error 49.80
# Epoch   700, train loss 0.001358, train error 0.00,  test loss 3.641295, test error 49.88
# Epoch   800, train loss 0.001133, train error 0.00,  test loss 3.716020, test error 49.80
# Epoch   900, train loss 0.000969, train error 0.00,  test loss 3.781123, test error 49.70
# Training model with 140 hidden variables
# Epoch     0, train loss 1.974306, train error 73.60,  test loss 1.911035, test error 74.60
# Epoch   100, train loss 0.036540, train error 0.00,  test loss 2.101368, test error 47.92
# Epoch   200, train loss 0.008124, train error 0.00,  test loss 2.577800, test error 48.15
# Epoch   300, train loss 0.004177, train error 0.00,  test loss 2.801675, test error 48.33
# Epoch   400, train loss 0.002707, train error 0.00,  test loss 2.949580, test error 48.55
# Epoch   500, train loss 0.001968, train error 0.00,  test loss 3.056428, test error 48.47
# Epoch   600, train loss 0.001530, train error 0.00,  test loss 3.143373, test error 48.55
# Epoch   700, train loss 0.001242, train error 0.00,  test loss 3.214849, test error 48.38
# Epoch   800, train loss 0.001040, train error 0.00,  test loss 3.275929, test error 48.45
# Epoch   900, train loss 0.000891, train error 0.00,  test loss 3.328862, test error 48.58
# Training model with 160 hidden variables
# Epoch     0, train loss 1.962948, train error 72.62,  test loss 1.899649, test error 73.00
# Epoch   100, train loss 0.028411, train error 0.00,  test loss 2.229357, test error 51.00
# Epoch   200, train loss 0.007109, train error 0.00,  test loss 2.651746, test error 50.67
# Epoch   300, train loss 0.003741, train error 0.00,  test loss 2.854579, test error 50.58
# Epoch   400, train loss 0.002458, train error 0.00,  test loss 2.991264, test error 50.75
# Epoch   500, train loss 0.001801, train error 0.00,  test loss 3.092127, test error 50.80
# Epoch   600, train loss 0.001406, train error 0.00,  test loss 3.174020, test error 50.95
# Epoch   700, train loss 0.001145, train error 0.00,  test loss 3.241686, test error 50.92
# Epoch   800, train loss 0.000961, train error 0.00,  test loss 3.300249, test error 50.88
# Epoch   900, train loss 0.000825, train error 0.00,  test loss 3.350700, test error 50.90
# Training model with 180 hidden variables
# Epoch     0, train loss 1.930884, train error 71.30,  test loss 1.842541, test error 73.12
# Epoch   100, train loss 0.023759, train error 0.00,  test loss 2.093232, test error 48.47
# Epoch   200, train loss 0.006475, train error 0.00,  test loss 2.459712, test error 48.00
# Epoch   300, train loss 0.003469, train error 0.00,  test loss 2.639421, test error 48.00
# Epoch   400, train loss 0.002302, train error 0.00,  test loss 2.763022, test error 48.05
# Epoch   500, train loss 0.001693, train error 0.00,  test loss 2.855034, test error 48.20
# Epoch   600, train loss 0.001327, train error 0.00,  test loss 2.928355, test error 48.22
# Epoch   700, train loss 0.001083, train error 0.00,  test loss 2.990234, test error 48.25
# Epoch   800, train loss 0.000911, train error 0.00,  test loss 3.042836, test error 48.22
# Epoch   900, train loss 0.000783, train error 0.00,  test loss 3.088610, test error 48.33
# Training model with 200 hidden variables
# Epoch     0, train loss 1.914348, train error 69.18,  test loss 1.857660, test error 72.57
# Epoch   100, train loss 0.021501, train error 0.00,  test loss 2.045299, test error 48.10
# Epoch   200, train loss 0.006209, train error 0.00,  test loss 2.374336, test error 48.47
# Epoch   300, train loss 0.003355, train error 0.00,  test loss 2.538903, test error 48.33
# Epoch   400, train loss 0.002240, train error 0.00,  test loss 2.652500, test error 48.55
# Epoch   500, train loss 0.001655, train error 0.00,  test loss 2.737261, test error 48.35
# Epoch   600, train loss 0.001301, train error 0.00,  test loss 2.805421, test error 48.50
# Epoch   700, train loss 0.001064, train error 0.00,  test loss 2.862063, test error 48.50
# Epoch   800, train loss 0.000896, train error 0.00,  test loss 2.911371, test error 48.45
# Epoch   900, train loss 0.000771, train error 0.00,  test loss 2.954384, test error 48.38
# Training model with 250 hidden variables
# Epoch     0, train loss 1.905392, train error 68.55,  test loss 1.835486, test error 70.90
# Epoch   100, train loss 0.016688, train error 0.00,  test loss 1.923200, test error 47.62
# Epoch   200, train loss 0.005270, train error 0.00,  test loss 2.182388, test error 47.10
# Epoch   300, train loss 0.002945, train error 0.00,  test loss 2.318179, test error 46.80
# Epoch   400, train loss 0.001990, train error 0.00,  test loss 2.410532, test error 46.95
# Epoch   500, train loss 0.001482, train error 0.00,  test loss 2.481180, test error 46.92
# Epoch   600, train loss 0.001171, train error 0.00,  test loss 2.538563, test error 46.92
# Epoch   700, train loss 0.000962, train error 0.00,  test loss 2.586990, test error 47.00
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.627980, test error 47.10
# Epoch   900, train loss 0.000701, train error 0.00,  test loss 2.664407, test error 47.08
# Training model with 300 hidden variables
# Epoch     0, train loss 1.849810, train error 66.95,  test loss 1.777267, test error 68.95
# Epoch   100, train loss 0.014708, train error 0.00,  test loss 1.845354, test error 46.70
# Epoch   200, train loss 0.004886, train error 0.00,  test loss 2.067127, test error 46.62
# Epoch   300, train loss 0.002759, train error 0.00,  test loss 2.185807, test error 46.55
# Epoch   400, train loss 0.001877, train error 0.00,  test loss 2.267624, test error 46.58
# Epoch   500, train loss 0.001404, train error 0.00,  test loss 2.329686, test error 46.55
# Epoch   600, train loss 0.001111, train error 0.00,  test loss 2.380649, test error 46.62
# Epoch   700, train loss 0.000915, train error 0.00,  test loss 2.422923, test error 46.58
# Epoch   800, train loss 0.000774, train error 0.00,  test loss 2.459720, test error 46.55
# Epoch   900, train loss 0.000669, train error 0.00,  test loss 2.491636, test error 46.53
# Training model with 400 hidden variables
# Epoch     0, train loss 1.861693, train error 66.80,  test loss 1.807284, test error 69.85
# Epoch   100, train loss 0.011691, train error 0.00,  test loss 1.770811, test error 46.17
# Epoch   200, train loss 0.004175, train error 0.00,  test loss 1.945339, test error 45.80
# Epoch   300, train loss 0.002416, train error 0.00,  test loss 2.041481, test error 45.80
# Epoch   400, train loss 0.001665, train error 0.00,  test loss 2.108639, test error 45.75
# Epoch   500, train loss 0.001255, train error 0.00,  test loss 2.161363, test error 45.58
# Epoch   600, train loss 0.000999, train error 0.00,  test loss 2.203597, test error 45.58
# Epoch   700, train loss 0.000825, train error 0.00,  test loss 2.239248, test error 45.53
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.270308, test error 45.50
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.297426, test error 45.35

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
